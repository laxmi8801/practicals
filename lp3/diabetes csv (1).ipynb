# %%
import pandas as pd

df = pd.read_csv('diabetes.csv')
op = df['Outcome']

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
arr = df['Glucose']

# %%
arr
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
arr[10:156]
# Out:
# 10     110
# 11     168
# 12     139
# 13     189
# 14     166
#       ...
# 151    114
# 152    156
# 153    153
# 154    188
# 155    152
# Name: Glucose, Length: 146, dtype: int64

# %%
series_obj = pd.Series(arr)
series_obj
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
reshape_arr = series_obj.values.reshape((6,128))
reshape_arr
# Out:
# array([[148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#         189, 166, 100, 118, 107, 103, 115, 126,  99, 196, 119, 143, 125,
#         147,  97, 145, 117, 109, 158,  88,  92, 122, 103, 138, 102,  90,
#         111, 180, 133, 106, 171, 159, 180, 146,  71, 103, 105, 103, 101,
#          88, 176, 150,  73, 187, 100, 146, 105,  84, 133,  44, 141, 114,
#          99, 109, 109,  95, 146, 100, 139, 126, 129,  79,   0,  62,  95,
#         131, 112, 113,  74,  83, 101, 137, 110, 106, 100, 136, 107,  80,
#         123,  81, 134, 142, 144,  92,  71,  93, 122, 163, 151, 125,  81,
#          85, 126,  96, 144,  83,  95, 171, 155,  89,  76, 160, 146, 124,
#          78,  97,  99, 162, 111, 107, 132, 113,  88, 120, 118],
#        [117, 105, 173, 122, 170,  84,  96, 125, 100,  93, 129, 105, 128,
#         106, 108, 108, 154, 102,  57, 106, 147,  90, 136, 114, 156, 153,
#         188, 152,  99, 109,  88, 163, 151, 102, 114, 100, 131, 104, 148,
# ...

# %%
'''flatning'''
reshape_arr.flatten()
# Out:
# array([148,  85, 183,  89, 137, 116,  78, 115, 197, 125, 110, 168, 139,
#        189, 166, 100, 118, 107, 103, 115, 126,  99, 196, 119, 143, 125,
#        147,  97, 145, 117, 109, 158,  88,  92, 122, 103, 138, 102,  90,
#        111, 180, 133, 106, 171, 159, 180, 146,  71, 103, 105, 103, 101,
#         88, 176, 150,  73, 187, 100, 146, 105,  84, 133,  44, 141, 114,
#         99, 109, 109,  95, 146, 100, 139, 126, 129,  79,   0,  62,  95,
#        131, 112, 113,  74,  83, 101, 137, 110, 106, 100, 136, 107,  80,
#        123,  81, 134, 142, 144,  92,  71,  93, 122, 163, 151, 125,  81,
#         85, 126,  96, 144,  83,  95, 171, 155,  89,  76, 160, 146, 124,
#         78,  97,  99, 162, 111, 107, 132, 113,  88, 120, 118, 117, 105,
#        173, 122, 170,  84,  96, 125, 100,  93, 129, 105, 128, 106, 108,
#        108, 154, 102,  57, 106, 147,  90, 136, 114, 156, 153, 188, 152,
#         99, 109,  88, 163, 151, 102, 114, 100, 131, 104, 148, 120, 110,
# ...

# %%
import numpy as np
df=df.loc[:,df.columns != 'Outcome'] 
df= df.replace(0,np.NaN)

# %%
df['Outcome'] = op

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0    148.0           72.0           35.0      NaN  33.6
# 1            1.0     85.0           66.0           29.0      NaN  26.6
# 2            8.0    183.0           64.0            NaN      NaN  23.3
# 3            1.0     89.0           66.0           23.0     94.0  28.1
# 4            NaN    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763         10.0    101.0           76.0           48.0    180.0  32.9
# 764          2.0    122.0           70.0           27.0      NaN  36.8
# 765          5.0    121.0           72.0           23.0    112.0  26.2
# 766          1.0    126.0           60.0            NaN      NaN  30.1
# 767          1.0     93.0           70.0           31.0      NaN  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
dmean = df.mean()
df = df.replace(np.NaN,dmean)

df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0       6.000000    148.0           72.0       35.00000  155.548223  33.6
# 1       1.000000     85.0           66.0       29.00000  155.548223  26.6
# 2       8.000000    183.0           64.0       29.15342  155.548223  23.3
# 3       1.000000     89.0           66.0       23.00000   94.000000  28.1
# 4       4.494673    137.0           40.0       35.00000  168.000000  43.1
# ..           ...      ...            ...            ...         ...   ...
# 763    10.000000    101.0           76.0       48.00000  180.000000  32.9
# 764     2.000000    122.0           70.0       27.00000  155.548223  36.8
# 765     5.000000    121.0           72.0       23.00000  112.000000  26.2
# 766     1.000000    126.0           60.0       29.15342  155.548223  30.1
# 767     1.000000     93.0           70.0       31.00000  155.548223  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (768, 9)

# %%
#knn and confusion matrix 
'''knn = bmi and skinthickness
knn = glocose and insulin'''
# Out:
# 'knn = bmi and skinthickness\nknn = glocose and insulin'

# %%
#x = [df.iloc[:,5].values + df.iloc[:,3].values]
x = df.iloc[:, [3,5]]
y = df.iloc[:,8].values

# %%
x
# Out:
#      SkinThickness   BMI
# 0         35.00000  33.6
# 1         29.00000  26.6
# 2         29.15342  23.3
# 3         23.00000  28.1
# 4         35.00000  43.1
# ..             ...   ...
# 763       48.00000  32.9
# 764       27.00000  36.8
# 765       23.00000  26.2
# 766       29.15342  30.1
# 767       31.00000  30.4
#
# [768 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.2)

# %%
from sklearn.neighbors import KNeighborsClassifier 

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

# %%
cm
# Out:
# array([[78, 17],
#        [36, 23]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
acc1 = (cm[0,0] + cm[1,1])/154
acc= accuracy_score(y_test,y_pred)
acc
# Out:
# 0.6558441558441559

# %%
err1 = (cm[0,1]+cm[1,0])/154
err1
# Out:
# 0.34415584415584416

# %%
pre1 = (cm[0,0])/(cm[0,0]+cm[1,0])
pre1
# Out:
# 0.6842105263157895

# %%
rec1 = (cm[0,0])/(cm[0,0]+cm[0,1])
rec1
# Out:
# 0.8210526315789474

# %%
f1_score1 = (2*pre1*rec1)/(pre1+rec1)
f1_score1
# Out:
# 0.7464114832535885

# %%
x1 = df.iloc[:, [1,4]]

# %%
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y,test_size= 0.2)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x1_train,y1_train)
# Out:
# KNeighborsClassifier()

# %%
y1_pred = knn.predict(x1_test)
cm1 = confusion_matrix(y1_test,y1_pred)
acc2 = (cm[0,0] + cm[1,1])/154
err2 = (cm[0,1]+cm[1,0])/154
pre2 = (cm[0,0])/(cm[0,0]+cm[1,0])
rec2 = (cm[0,0])/(cm[0,0]+cm[0,1])
f1_score2 = (2*pre2*rec2)/(pre2+rec2)

# %%
cm1
# Out:
# array([[78, 13],
#        [28, 35]], dtype=int64)

# %%
from tabulate import tabulate
mydata = [
    ["accuracy", acc1,acc2],
    ["error",err1,err2],
    ["precesion",pre2,pre2],
    ["recall",rec1,rec2],
    ["f1_score",f1_score1,f1_score2]
]
 
# create header
head = ["bmi and skinthickness", "glocose and insulin"]
 
# display table
print(tabulate(mydata, headers=head, tablefmt="grid"))
# Out:
# +-----------+-------------------------+-----------------------+
# |           |   bmi and skinthickness |   glocose and insulin |
# +===========+=========================+=======================+
# | accuracy  |                0.655844 |              0.655844 |
# +-----------+-------------------------+-----------------------+
# | error     |                0.344156 |              0.344156 |
# +-----------+-------------------------+-----------------------+
# | precesion |                0.684211 |              0.684211 |
# +-----------+-------------------------+-----------------------+
# | recall    |                0.821053 |              0.821053 |
# +-----------+-------------------------+-----------------------+
# | f1_score  |                0.746411 |              0.746411 |
# +-----------+-------------------------+-----------------------+

# %%
from sklearn.metrics import precision_score,recall_score,accuracy_score,f1_score

prec_1 = precision_score(y_test,y_pred)
rec_1 = recall_score(y_test,y_pred)
acc_1 = accuracy_score(y_test,y_pred)
f1_1 = f1_score(y_test,y_pred)

# %%
from tabulate import tabulate
mydata = [
    ["accuracy", acc1,acc_1],
    ["error",err1,err2],
    ["precesion",pre1,prec_1],
    ["recall",rec1,rec_1],
    ["f1_score",f1_score1,f1_1]
]
 
# create header
head = ["manual", "actual"]
 
# display table
print(tabulate(mydata, headers=head, tablefmt="grid"))
# Out:
# +-----------+----------+----------+
# |           |   manual |   actual |
# +===========+==========+==========+
# | accuracy  | 0.655844 | 0.655844 |
# +-----------+----------+----------+
# | error     | 0.344156 | 0.344156 |
# +-----------+----------+----------+
# | precesion | 0.684211 | 0.575    |
# +-----------+----------+----------+
# | recall    | 0.821053 | 0.389831 |
# +-----------+----------+----------+
# | f1_score  | 0.746411 | 0.464646 |
# +-----------+----------+----------+
